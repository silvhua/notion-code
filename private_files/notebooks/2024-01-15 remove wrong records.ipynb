# %% [markdown]
# # Title
# []()

# %%
import sys
sys.path.append(r"/home/silvhua/custom_python")
sys.path.append(r"/home/silvhua/repositories/notion/src")
from silvhua import *
from notion_functions import *

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', 100)
# pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %% [markdown]
# # Load Data

# %%
path = '../data'
filename = 'notion_df.sav'
df = loadpickle(filename, path)
df
# Out:
# 	Time completed: 2024-01-15 00:53:31.861415
# Dataframe shape:  (1321, 16)
# DataFrame columns: ['Name', 'created_time', 'Task Tag', 'Flag', 'Elapsed', 'Task Name', 'Task Project tags', 'Task Parent-task', 'Task Sub-tasks', 'Task Project name', 'start time', 'end time', 'Roadmap Item', 'url', 'id', 'Notes']
#                    Name              created_time  Task Tag  Flag   Elapsed  \
# 0      2023-09-01 09:48 2023-09-01 09:48:00-07:00    [life]  None  0.783333
# 1      2023-09-01 10:55 2023-09-01 10:55:00-07:00    [life]  None  0.333333
# 2     ;2023-09-01 10:57 2023-09-01 10:57:00-07:00  [Ginkgo]  None  0.766667
# 3      2023-09-01 11:59 2023-09-01 11:59:00-07:00  [Ginkgo]  None  0.766667
# 4      2023-09-01 13:30 2023-09-01 13:30:00-07:00    [life]  None  1.416667
# ...                 ...                       ...       ...   ...       ...
# 1316   2024-01-13 12:08 2024-01-13 12:07:00-08:00    [life]  None  5.133333
# 1317         2024-01-14 2024-01-14 08:07:00-08:00    [life]  None       0.3
# 1318   2024-01-14 08:21 2024-01-14 08:21:00-08:00    [life]  None  1.666667
# 1319   2024-01-14 10:32 2024-01-14 10:32:00-08:00        []  None  0.566667
# 1320   2024-01-14 18:06 2024-01-14 18:06:00-08:00    [life]  None     20.05
#
#                                               Task Name Task Project tags  \
# 0                          CloudWolf CCP 75% of content         [tech ed]
# 1      create social media content showing my expertise            [life]
# 2     Look into WriteSonic AI social media tool (Ruo...     [Ginkgo work]
# 3                                 Ginkgo sprint meeting     [Ginkgo work]
# 4                          CloudWolf CCP 75% of content         [tech ed]
# ...                                                 ...               ...
# 1316       create front end script for invoices: Ginkgo  [tech ed, admin]
# 1317                    CloudWolf virtual study session         [tech ed]
# 1318       create front end script for invoices: Ginkgo  [tech ed, admin]
# 1319              Kinesiology mentorship meeting: Lydia       [volunteer]
# 1320       create front end script for invoices: Ginkgo  [tech ed, admin]
#
#      Task Parent-task                                     Task Sub-tasks  \
# 0              [None]                                             [None]
# 1              [None]  [[3d5b9f63-419e-4d4c-904a-f0d66f5951a5, e54598...
# 2              [None]                                             [None]
# 3              [None]                                             [None]
# 4              [None]                                             [None]
# ...               ...                                                ...
# 1316           [None]                                             [None]
# 1317           [None]                                             [None]
# 1318           [None]                                             [None]
# 1319           [None]                                             [None]
# 1320           [None]                                             [None]
#
#                                    Task Project name start time end time  \
# 0     AWS Certified Cloud Practitioner certification      09:48    10:35
# 1                                 career positioning      10:35    10:55
# 2                     knowledge library social media      10:57    11:43
# 3                                       Ginkgo Admin      12:00    12:46
# 4     AWS Certified Cloud Practitioner certification      13:30    14:55
# ...                                              ...        ...      ...
# 1316                                Notion analytics      12:12    17:20
# 1317  AWS Certified Cloud Practitioner certification      08:03    08:21
# 1318                                Notion analytics      08:21    10:01
# 1319              UBC Kinesiology Mentorship program      10:32    11:06
# 1320                                Notion analytics       None    20:03
#
#      Roadmap Item                                                url   id  \
# 0              []  https://www.notion.so/2023-09-01-09-48-a0526a3...  851
# 1              []  https://www.notion.so/2023-09-01-10-55-68ed3f5...  850
# 2              []  https://www.notion.so/2023-09-01-10-57-ce0b078...  849
# 3              []  https://www.notion.so/2023-09-01-11-59-3e167f5...  848
# 4              []  https://www.notion.so/2023-09-01-13-30-33447cd...  847
# ...           ...                                                ...  ...
# 1316           []  https://www.notion.so/2024-01-13-12-08-6920b24...   74
# 1317           []  https://www.notion.so/2024-01-14-1a6794db63b14...   75
# 1318           []  https://www.notion.so/2024-01-14-08-21-e6227f4...   76
# 1319           []  https://www.notion.so/2024-01-14-10-32-8ea5dcf...   77
# 1320           []  https://www.notion.so/2024-01-14-18-06-82eb5d5...   78
#
#      Notes
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 1316  None
# 1317  None
# 1318  None
# 1319  None
# 1320  None
#
# [1321 rows x 16 columns]

# %% [markdown]
# # *End of Page*
