# %% [markdown]
# # Title
# []()

# %%
import pandas as pd
import sys
sys.path.append(r"/home/silvhua/custom_python")
from silvhua import *
# from datetime import datetime

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', 100)
# pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
path = '/home/silvhua/repositories/notion/data/'
filename = 'notion_time_tracking_3m_2023-12-21_2334.json'
data = load_json(filename, path)
data
# Out:
# [{'object': 'page',
#   'id': 'a7f579a6-5439-43b9-9e5d-f695889ac88f',
#   'created_time': '2023-12-01T04:26:00.000Z',
#   'last_edited_time': '2023-12-01T08:00:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': 'b25bcc0d-a83f-4a66-8e1b-ef8d00bc8284',
#          'name': 'life',
#          'color': 'gray'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-12-01T04:26:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 3.566666666667}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 26}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 24}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '29889961-8494-4d87-8458-567104699cc2'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '20:26', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '20:26',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 20}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '24:00', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '24:00',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': ';2023-11-30 20:26', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': ';2023-11-30 20:26',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-20-26-a7f579a6543943b99e5df695889ac88f',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-20-26-a7f579a6543943b99e5df695889ac88f'},
#  {'object': 'page',
#   'id': '3b00d2c2-7b81-4443-834b-84ed72b2ec7d',
#   'created_time': '2023-12-01T00:44:00.000Z',
#   'last_edited_time': '2023-12-01T04:26:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': 'b25bcc0d-a83f-4a66-8e1b-ef8d00bc8284',
#          'name': 'life',
#          'color': 'gray'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-12-01T00:44:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 1.2}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 3}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 15}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 17}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '29889961-8494-4d87-8458-567104699cc2'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '16:03', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '16:03',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 16}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '17:15', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '17:15',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 16:44;ts', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 16:44;ts',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-16-44-ts-3b00d2c27b814443834b84ed72b2ec7d',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-16-44-ts-3b00d2c27b814443834b84ed72b2ec7d'},
#  {'object': 'page',
#   'id': 'f93a93d3-5fbc-4c9d-a5d1-ceee90b098ba',
#   'created_time': '2023-11-30T22:53:00.000Z',
#   'last_edited_time': '2023-12-01T04:26:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': 'b25bcc0d-a83f-4a66-8e1b-ef8d00bc8284',
#          'name': 'life',
#          'color': 'gray'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T22:53:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 1.166666666667}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 53}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 3}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 16}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '29889961-8494-4d87-8458-567104699cc2'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '14:53', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '14:53',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 14}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '16:03', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '16:03',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 14:53', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 14:53',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-14-53-f93a93d35fbc4c9da5d1ceee90b098ba',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-14-53-f93a93d35fbc4c9da5d1ceee90b098ba'},
#  {'object': 'page',
#   'id': '6e291503-5d5c-42ea-a86b-7813c4164b05',
#   'created_time': '2023-11-30T20:25:00.000Z',
#   'last_edited_time': '2023-11-30T20:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '53fc9868-911f-4c97-b5e8-9fd704e81ade',
#          'name': 'Ginkgo',
#          'color': 'green'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T20:25:00.000Z'},
#    'Notes': {'id': 'GKD%3C',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '2023-11-30 12:25 Publish exercise 541, first exercise for TMA to try fixing B-A loop issue.\n—',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 12:25 Publish exercise 541, first exercise for TMA to try fixing B-A loop issue.\n—',
#       'href': None}]},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.316666666667}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 25}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 44}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 12}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '196d64f7-6dc4-4b46-8178-2679482d803e'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '12:25', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '12:25',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 12}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '12:44', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '12:44',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 12:25', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 12:25',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-12-25-6e2915035d5c42eaa86b7813c4164b05',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-12-25-6e2915035d5c42eaa86b7813c4164b05'},
#  {'object': 'page',
#   'id': '1b4cc854-fde5-4e4b-8e1d-d1c57bb3fc8f',
#   'created_time': '2023-11-30T19:55:00.000Z',
#   'last_edited_time': '2023-11-30T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': 'b25bcc0d-a83f-4a66-8e1b-ef8d00bc8284',
#          'name': 'life',
#          'color': 'gray'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T19:55:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.6}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 48}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 24}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 12}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '1e819f7b-da96-45ac-9470-b0c108c3c9d2'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '11:48', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '11:48',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 11}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '12:24', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '12:24',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 11:55', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 11:55',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-11-55-1b4cc854fde54e4b8e1dd1c57bb3fc8f',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-11-55-1b4cc854fde54e4b8e1dd1c57bb3fc8f'},
#  {'object': 'page',
#   'id': 'b4107914-0a39-49c7-b639-61c8facd801c',
#   'created_time': '2023-11-30T19:26:00.000Z',
#   'last_edited_time': '2023-11-30T19:39:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '53fc9868-911f-4c97-b5e8-9fd704e81ade',
#          'name': 'Ginkgo',
#          'color': 'green'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T19:26:00.000Z'},
#    'Notes': {'id': 'GKD%3C',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '2023-11-30 11:26\nThese are the 9 exercise IDs that look bad when looping from B to A: 30, 189, 195, 371, 400, 492, 540, 670, 671\n—',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 11:26\nThese are the 9 exercise IDs that look bad when looping from B to A: 30, 189, 195, 371, 400, 492, 540, 670, 671\n—',
#       'href': None}]},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.183333333333}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 27}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 38}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 11}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '196d64f7-6dc4-4b46-8178-2679482d803e'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '11:27', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '11:27',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 11}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '11:38', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '11:38',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 11:26', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 11:26',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-11-26-b41079140a3949c7b63961c8facd801c',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-11-26-b41079140a3949c7b63961c8facd801c'},
#  {'object': 'page',
#   'id': 'd03e6f6f-41d8-41ae-8a39-1aa2d298c81d',
#   'created_time': '2023-11-30T19:05:00.000Z',
#   'last_edited_time': '2023-11-30T19:23:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '53fc9868-911f-4c97-b5e8-9fd704e81ade',
#          'name': 'Ginkgo',
#          'color': 'green'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T19:05:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.35}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 2}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 23}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 11}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': 'a6405712-c50c-4559-8d1f-e763a5cf7dae'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '11:02', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '11:02',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 11}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '11:23', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '11:23',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 11:02', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 11:02',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-11-02-d03e6f6f41d841ae8a391aa2d298c81d',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-11-02-d03e6f6f41d841ae8a391aa2d298c81d'},
#  {'object': 'page',
#   'id': 'bda498a5-e6f6-47dd-8ada-b725669576f1',
#   'created_time': '2023-11-30T18:14:00.000Z',
#   'last_edited_time': '2023-11-30T19:05:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': 'b25bcc0d-a83f-4a66-8e1b-ef8d00bc8284',
#          'name': 'life',
#          'color': 'gray'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T18:14:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.866666666667}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 10}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 2}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 11}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': 'afc41cac-f014-441c-a13b-223a0a2e482b'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '10:10', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '10:10',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 10}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '11:02', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '11:02',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 10:14', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 10:14',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-10-14-bda498a5e6f647dd8adab725669576f1',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-10-14-bda498a5e6f647dd8adab725669576f1'},
#  {'object': 'page',
#   'id': '00a94768-dae6-4b70-989d-dd8f0238eeed',
#   'created_time': '2023-11-30T16:58:00.000Z',
#   'last_edited_time': '2023-11-30T16:59:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '53fc9868-911f-4c97-b5e8-9fd704e81ade',
#          'name': 'Ginkgo',
#          'color': 'green'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T16:58:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.233333333333}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 45}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 59}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 8}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '1020f71e-cc88-44b5-847c-711b9f28f68a'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '08:45', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '08:45',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 8}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '08:59', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '08:59',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 08:58', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 08:58',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-08-58-00a94768dae64b70989ddd8f0238eeed',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-08-58-00a94768dae64b70989ddd8f0238eeed'},
#  {'object': 'page',
#   'id': '148db728-8d0d-46fa-995f-8a1f00180c61',
#   'created_time': '2023-11-30T16:17:00.000Z',
#   'last_edited_time': '2023-11-30T16:45:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '53fc9868-911f-4c97-b5e8-9fd704e81ade',
#          'name': 'Ginkgo',
#          'color': 'green'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T16:17:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.466666666667}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 17}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 45}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 8}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '330197b7-8921-4f6f-81b2-a7c942df647c'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '08:17', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '08:17',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 8}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '08:45', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '08:45',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-30 08:17', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-30 08:17',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-30-08-17-148db7288d0d46fa995f8a1f00180c61',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-30-08-17-148db7288d0d46fa995f8a1f00180c61'},
#  {'object': 'page',
#   'id': '8c137311-d17d-45c0-baf5-6821b9b6693b',
#   'created_time': '2023-11-30T01:39:00.000Z',
#   'last_edited_time': '2023-11-30T06:34:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': 'b25bcc0d-a83f-4a66-8e1b-ef8d00bc8284',
#          'name': 'life',
#          'color': 'gray'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T01:39:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.433333333333}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 39}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 5}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 18}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '87d4f261-9eef-4dec-9b2e-36eabc2fc071'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '17:39', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '17:39',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 17}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '18:05', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '18:05',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-29 17:39', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-29 17:39',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-29-17-39-8c137311d17d45c0baf56821b9b6693b',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-29-17-39-8c137311d17d45c0baf56821b9b6693b'},
#  {'object': 'page',
#   'id': '7321bf84-742d-4778-8663-09b894e13f81',
#   'created_time': '2023-11-30T00:48:00.000Z',
#   'last_edited_time': '2023-11-30T01:15:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '53fc9868-911f-4c97-b5e8-9fd704e81ade',
#          'name': 'Ginkgo',
#          'color': 'green'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-30T00:48:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.45}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 48}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 15}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 17}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '330197b7-8921-4f6f-81b2-a7c942df647c'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '16:48', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '16:48',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 16}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '17:15', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '17:15',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-29 16:48', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-29 16:48',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-29-16-48-7321bf84742d4778866309b894e13f81',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-29-16-48-7321bf84742d4778866309b894e13f81'},
#  {'object': 'page',
#   'id': 'f44bdc46-1e43-461c-889b-c441cab5c7ca',
#   'created_time': '2023-11-29T22:57:00.000Z',
#   'last_edited_time': '2023-11-30T00:11:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
# ...
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-21 16:25', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-21 16:25',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-21-16-25-72e17b1f9ec44e95a542ea6590f8f52a',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-21-16-25-72e17b1f9ec44e95a542ea6590f8f52a'},
#  {'object': 'page',
#   'id': '5349c619-1bd1-4184-a13f-84d2fe3a16d7',
#   'created_time': '2023-11-22T00:05:00.000Z',
#   'last_edited_time': '2023-11-22T00:25:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '53fc9868-911f-4c97-b5e8-9fd704e81ade',
#          'name': 'Ginkgo',
#          'color': 'green'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-22T00:05:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.183333333333}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 5}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 16}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 16}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '330197b7-8921-4f6f-81b2-a7c942df647c'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '16:05', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '16:05',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 16}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '16:16', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '16:16',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-21 16:05', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-21 16:05',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-21-16-05-5349c6191bd14184a13f84d2fe3a16d7',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-21-16-05-5349c6191bd14184a13f84d2fe3a16d7'},
#  {'object': 'page',
#   'id': 'b30b9804-9d42-471d-bddf-1d1c836c12b9',
#   'created_time': '2023-11-21T22:50:00.000Z',
#   'last_edited_time': '2023-11-22T06:55:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': 'b25bcc0d-a83f-4a66-8e1b-ef8d00bc8284',
#          'name': 'life',
#          'color': 'gray'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-21T22:50:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.95}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 50}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 47}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 15}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '1e819f7b-da96-45ac-9470-b0c108c3c9d2'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '14:50', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '14:50',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 14}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '15:47', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '15:47',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-21 14:50', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-21 14:50',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-21-14-50-b30b98049d42471dbddf1d1c836c12b9',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-21-14-50-b30b98049d42471dbddf1d1c836c12b9'},
#  {'object': 'page',
#   'id': '88be7541-b411-424a-af6e-4c2e44427c86',
#   'created_time': '2023-11-21T22:43:00.000Z',
#   'last_edited_time': '2023-11-21T22:47:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '6ce47b19-7220-436a-b075-7f16c617d6ba',
#          'name': 'Defy Time Fitness',
#          'color': 'blue'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-21T22:43:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.033333333333}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 44}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 46}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 14}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': '4bc9113c-20f0-4e60-9acb-bdb6ab279be9'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '14:44', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '14:44',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 14}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '14:46', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '14:46',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-21 14:44', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-21 14:44',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-21-14-44-88be7541b411424aaf6e4c2e44427c86',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-21-14-44-88be7541b411424aaf6e4c2e44427c86'},
#  {'object': 'page',
#   'id': 'e31f8255-af9d-4caa-a46d-f04e20c32a94',
#   'created_time': '2023-11-21T20:24:00.000Z',
#   'last_edited_time': '2023-11-21T20:56:00.000Z',
#   'created_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'last_edited_by': {'object': 'user',
#    'id': 'f4b38e73-d5f6-43c6-99b5-a5cbf1fb60c2'},
#   'cover': None,
#   'icon': None,
#   'parent': {'type': 'database_id',
#    'database_id': 'bcd0d296-955b-4b92-8621-e4b96ebad29c'},
#   'archived': False,
#   'properties': {'Task Tag': {'id': '%3BixQ',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'multi_select',
#        'multi_select': [{'id': '53fc9868-911f-4c97-b5e8-9fd704e81ade',
#          'name': 'Ginkgo',
#          'color': 'green'}]}],
#      'function': 'show_original'}},
#    'Flag': {'id': 'B%5DwL', 'type': 'multi_select', 'multi_select': []},
#    'Created time': {'id': 'B%60jT',
#     'type': 'created_time',
#     'created_time': '2023-11-21T20:24:00.000Z'},
#    'Notes': {'id': 'GKD%3C', 'type': 'rich_text', 'rich_text': []},
#    'Elapsed': {'id': 'W%5Bxa',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 0.533333333333}},
#    'Projects': {'id': 'WgYt',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Start min': {'id': 'Xun_',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 24}},
#    'summary': {'id': '%5EhRz',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'End min': {'id': '%60s%3AV',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 56}},
#    'follow up task': {'id': 'bMxq',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'URL': {'id': 'bidc', 'type': 'url', 'url': None},
#    'End hr': {'id': 'ex%3C%40',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 12}},
#    'Tasks': {'id': 'iYKi',
#     'type': 'relation',
#     'relation': [{'id': 'a2700a95-3881-40a7-921f-732e8a8617a0'}],
#     'has_more': False},
#    'Project tag': {'id': 'nWB%40',
#     'type': 'rollup',
#     'rollup': {'type': 'array', 'array': [], 'function': 'show_original'}},
#    'start time': {'id': 'w%3FoM',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '12:24', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '12:24',
#       'href': None}]},
#    'Project (Rollup)': {'id': 'w%3Ftw',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_unique'}},
#    'Start hr': {'id': 'wZPX',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 12}},
#    'end time': {'id': 'xIny',
#     'type': 'rich_text',
#     'rich_text': [{'type': 'text',
#       'text': {'content': '12:56', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '12:56',
#       'href': None}]},
#    'Roadmap Item': {'id': 'y%7BQt',
#     'type': 'rollup',
#     'rollup': {'type': 'array',
#      'array': [{'type': 'relation', 'relation': []}],
#      'function': 'show_original'}},
#    'Name': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': '2023-11-21 12:24', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': '2023-11-21 12:24',
#       'href': None}]}},
#   'url': 'https://www.notion.so/2023-11-21-12-24-e31f8255af9d4caaa46df04e20c32a94',
#   'public_url': 'https://sand-gallimimus-e92.notion.site/2023-11-21-12-24-e31f8255af9d4caaa46df04e20c32a94'}]

# %%
pd.DataFrame(data)
# Out:
#    object                                    id              created_time  \
# 0    page  a7f579a6-5439-43b9-9e5d-f695889ac88f  2023-12-01T04:26:00.000Z
# 1    page  3b00d2c2-7b81-4443-834b-84ed72b2ec7d  2023-12-01T00:44:00.000Z
# 2    page  f93a93d3-5fbc-4c9d-a5d1-ceee90b098ba  2023-11-30T22:53:00.000Z
# 3    page  6e291503-5d5c-42ea-a86b-7813c4164b05  2023-11-30T20:25:00.000Z
# 4    page  1b4cc854-fde5-4e4b-8e1d-d1c57bb3fc8f  2023-11-30T19:55:00.000Z
# ..    ...                                   ...                       ...
# 95   page  72e17b1f-9ec4-4e95-a542-ea6590f8f52a  2023-11-22T00:25:00.000Z
# 96   page  5349c619-1bd1-4184-a13f-84d2fe3a16d7  2023-11-22T00:05:00.000Z
# 97   page  b30b9804-9d42-471d-bddf-1d1c836c12b9  2023-11-21T22:50:00.000Z
# 98   page  88be7541-b411-424a-af6e-4c2e44427c86  2023-11-21T22:43:00.000Z
# 99   page  e31f8255-af9d-4caa-a46d-f04e20c32a94  2023-11-21T20:24:00.000Z
#
#             last_edited_time  \
# 0   2023-12-01T08:00:00.000Z
# 1   2023-12-01T04:26:00.000Z
# 2   2023-12-01T04:26:00.000Z
# 3   2023-11-30T20:45:00.000Z
# 4   2023-11-30T20:24:00.000Z
# ..                       ...
# 95  2023-11-22T00:25:00.000Z
# 96  2023-11-22T00:25:00.000Z
# 97  2023-11-22T06:55:00.000Z
# 98  2023-11-21T22:47:00.000Z
# 99  2023-11-21T20:56:00.000Z
#
#                                            created_by  \
# 0   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# 1   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# 2   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# 3   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# 4   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# ..                                                ...
# 95  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# 96  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# 97  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# 98  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
# 99  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...
#
#                                        last_edited_by cover  icon  \
# 0   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# 1   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# 2   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# 3   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# 4   {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# ..                                                ...   ...   ...
# 95  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# 96  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# 97  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# 98  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
# 99  {'object': 'user', 'id': 'f4b38e73-d5f6-43c6-9...  None  None
#
#                                                parent  archived  \
# 0   {'type': 'database_id', 'database_id': 'bcd0d2...     False
# 1   {'type': 'database_id', 'database_id': 'bcd0d2...     False
# 2   {'type': 'database_id', 'database_id': 'bcd0d2...     False
# 3   {'type': 'database_id', 'database_id': 'bcd0d2...     False
# 4   {'type': 'database_id', 'database_id': 'bcd0d2...     False
# ..                                                ...       ...
# 95  {'type': 'database_id', 'database_id': 'bcd0d2...     False
# 96  {'type': 'database_id', 'database_id': 'bcd0d2...     False
# 97  {'type': 'database_id', 'database_id': 'bcd0d2...     False
# 98  {'type': 'database_id', 'database_id': 'bcd0d2...     False
# 99  {'type': 'database_id', 'database_id': 'bcd0d2...     False
#
#                                            properties  \
# 0   {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# 1   {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# 2   {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# 3   {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# 4   {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# ..                                                ...
# 95  {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# 96  {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# 97  {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# 98  {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
# 99  {'Task Tag': {'id': '%3BixQ', 'type': 'rollup'...
#
#                                                   url  \
# 0   https://www.notion.so/2023-11-30-20-26-a7f579a...
# 1   https://www.notion.so/2023-11-30-16-44-ts-3b00...
# 2   https://www.notion.so/2023-11-30-14-53-f93a93d...
# 3   https://www.notion.so/2023-11-30-12-25-6e29150...
# 4   https://www.notion.so/2023-11-30-11-55-1b4cc85...
# ..                                                ...
# 95  https://www.notion.so/2023-11-21-16-25-72e17b1...
# 96  https://www.notion.so/2023-11-21-16-05-5349c61...
# 97  https://www.notion.so/2023-11-21-14-50-b30b980...
# 98  https://www.notion.so/2023-11-21-14-44-88be754...
# 99  https://www.notion.so/2023-11-21-12-24-e31f825...
#
#                                            public_url
# 0   https://sand-gallimimus-e92.notion.site/2023-1...
# 1   https://sand-gallimimus-e92.notion.site/2023-1...
# 2   https://sand-gallimimus-e92.notion.site/2023-1...
# 3   https://sand-gallimimus-e92.notion.site/2023-1...
# 4   https://sand-gallimimus-e92.notion.site/2023-1...
# ..                                                ...
# 95  https://sand-gallimimus-e92.notion.site/2023-1...
# 96  https://sand-gallimimus-e92.notion.site/2023-1...
# 97  https://sand-gallimimus-e92.notion.site/2023-1...
# 98  https://sand-gallimimus-e92.notion.site/2023-1...
# 99  https://sand-gallimimus-e92.notion.site/2023-1...
#
# [100 rows x 13 columns]

# %% [markdown]
# # *End of Page*
