# %% [markdown]
# # Title
# []()

# %%
import sys
sys.path.append(r"/home/silvhua/custom_python")
sys.path.append(r"/home/silvhua/repositories/notion/src")
from silvhua import *
from notion_functions import *

# %%
# set the option to wrap text within cells
pd.set_option('display.max_colwidth', 100)
# pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
path = '/home/silvhua/repositories/notion/data/'
filename = 'notion_time_tracking_parsed_week_2023-12-26_1706.json'
data = load_json(filename, path)
data
# Out:
# {'c5d3d76a-fb88-4f0f-9391-2796764896bc': {'Task Tag': None,
#   'Flag': None,
#   'Notes': None,
#   'Elapsed': -13.383333333333,
#   'Tasks': None,
#   'start time': '13:23',
#   'end time': None,
#   'Roadmap Item': None,
#   'Name': '2023-12-26 13:23s'},
#  'b34fba8f-2298-4d66-9b23-988e3c7683ec': {'Task Tag': ['life'],
#   'Flag': None,
#   'Notes': None,
#   'Elapsed': 0.933333333333,
#   'Task Name': ['Wrangle time tracking data'],
#   'Task Project tags': [['life', 'tech ed', 'admin']],
#   'Task Project': ['3d90e406-46c9-4468-b70d-e9e3bf2653f9'],
#   'Task Parent-task': [None],
#   'Task Sub-tasks': [None],
#   'Task Project name': ['Notion analytics'],
#   'start time': '11:21',
#   'end time': '12:17',
#   'Roadmap Item': [],
#   'Name': '2023-12-26 11:21'},
#  'd4691dbc-36a5-47e9-a86f-bb6930357ed7': {'Task Tag': ['life'],
#   'Flag': None,
#   'Notes': None,
#   'Elapsed': 0.35,
#   'Task Name': ['weekly/monthly reflection'],
#   'Task Project tags': [['life']],
#   'Task Project': ['c90b2ad0-e51b-4d1a-8d51-82d9b37a1290'],
#   'Task Parent-task': [None],
#   'Task Sub-tasks': [None],
#   'Task Project name': ['Inner work'],
#   'start time': '00:44',
#   'end time': '01:05',
#   'Roadmap Item': [],
#   'Name': '2023-12-26 00:44'},
#  'fec5e2b8-4bd7-4635-9406-c31d961d6a5f': {'Task Tag': ['life'],
#   'Flag': None,
#   'Notes': None,
#   'Elapsed': 3.116666666667,
#   'Task Name': ['Wrangle time tracking data'],
#   'Task Project tags': [['life', 'tech ed', 'admin']],
#   'Task Project': ['3d90e406-46c9-4468-b70d-e9e3bf2653f9'],
#   'Task Parent-task': [None],
#   'Task Sub-tasks': [None],
#   'Task Project name': ['Notion analytics'],
#   'start time': '15:00',
#   'end time': '18:07',
#   'Roadmap Item': [],
#   'Name': '2023-12-25 15:00'},
#  '6eeb90ff-10bd-4702-9e54-c923392beca0': {'Task Tag': ['life'],
#   'Flag': None,
#   'Notes': None,
#   'Elapsed': 3.333333333333,
#   'Task Name': ['create scripts to pull time tracking data'],
#   'Task Project tags': [['life', 'tech ed', 'admin']],
#   'Task Project': ['3d90e406-46c9-4468-b70d-e9e3bf2653f9'],
#   'Task Parent-task': [None],
#   'Task Sub-tasks': [None],
#   'Task Project name': ['Notion analytics'],
#   'start time': '11:40',
#   'end time': '15:00',
#   'Roadmap Item': [],
#   'Name': '2023-12-25 15:49 '}}

# %%
pd.DataFrame(data).transpose()
# Out:
#                                      Task Tag  Flag Notes    Elapsed Tasks  \
# c5d3d76a-fb88-4f0f-9391-2796764896b
# fec5e2b8-4bd7-4635-9406-c31d961d6a5f           [None]         [None]
# 6eeb90ff-10bd-4702-9e54-c923392beca0           [None]         [None]
#
#                                        Task Project name
# c5d3d76a-fb88-4f0f-9391-2796764896bc                 NaN
# b34fba8f-2298-4d66-9b23-988e3c7683ec  [Notion analytics]
# d4691dbc-36a5-47e9-a86f-bb6930357ed7        [Inner work]
# fec5e2b8-4bd7-4635-9406-c31d961d6a5f  [Notion analytics]
# 6eeb90ff-10bd-4702-9e54-c923392beca0  [Notion analytics]

# %% [markdown]
# # Iteration 1

# %%
def create_notion_df(filename, filepath):
    data = load_json(filename, filepath)
    df = pd.DataFrame(data).transpose()
    columns = df.columns.tolist()
    # Remove 'Name' from columns
    columns.remove('Name')
    # make 'Name' the first column
    df.index.name = 'id'
    columns = ['Name'] + columns + ['id']
    # Turn the index into a column
    df = df.reset_index()
    return df[columns]

df = create_notion_df(filename, path)
df
# Out:
#                 Name Task Tag  Flag Notes    Elapsed Tasks start time  \
# 0  2023-12-26 13:23s     None  None  None -13.383333  None      13:23
# 1   2023-12-26 11:21   [life]  None  None   0.933333   NaN      11:21
# 2   2023-12-26 00:44   [life]  None  None       0.35   NaN      00:44
# 3   2023-12-25 15:00   [life]  None  None   3.116667   NaN      15:00
# 4  2023-12-25 15:49    [life]  None  None   3.333333   NaN      11:40
#
#   end time Roadmap Item                                    Task Name  \
# 0     None         None                                          NaN
# 1    12:17           []                 [Wrangle time tracking data]
# 2    01:05           []                  [weekly/monthly reflection]
# 3    18:07           []                 [Wrangle time tracking data]
# 4    15:00           []  [create scripts to pull time tracking data]
#
#           Task Project tags                            Task Project  \
# 0                       NaN                                     NaN
# 1  [[life, tech ed, admin]]  [3d90e406-46c9-4468-b70d-e9e3bf2653f9]
# 2                  [[life]]  [c90b2ad0-e51b-4d1a-8d51-82d9b37a1290]
# 3  [[life, tech ed, admin]]  [3d90e406-46c9-4468-b70d-e9e3bf2653f9]
# 4  [[life, tech ed, admin]]  [3d90e406-46c9-4468-b70d-e9e3bf2653f9]
#
#   Task Parent-task Task Sub-tasks   Task Project name  \
# 0              NaN            NaN                 NaN
# 1           [None]         [None]  [Notion analytics]
# 2           [None]         [None]        [Inner work]
# 3           [None]         [None]  [Notion analytics]
# 4           [None]         [None]  [Notion analytics]
#
#                                      id
# 0  c5d3d76a-fb88-4f0f-9391-2796764896bc
# 1  b34fba8f-2298-4d66-9b23-988e3c7683ec
# 2  d4691dbc-36a5-47e9-a86f-bb6930357ed7
# 3  fec5e2b8-4bd7-4635-9406-c31d961d6a5f
# 4  6eeb90ff-10bd-4702-9e54-c923392beca0

# %% [markdown]
# # *End of Page*
